# %% [markdown]
# # MLflow Hyperparameter Tuning
#
# `Hyperparameter Tuning`:
#
# - the process to **select the optimal configuration settings** for a machine learning model before the training process begins in order to **maximize its predictive accuracy**.

# %% [markdown]
# ## Environment

# %%
from src.tracking import tracking_uri
import sys
from pathlib import Path

import mlflow
import torch

# data
ROOT = Path.cwd().parent
sys.path.insert(0, str(ROOT))

RAW = ROOT / "data" / "raw"
PROCESSED = ROOT / "data" / "processed"

# mlflow instance
mlflow.set_tracking_uri(tracking_uri())

# print versions and mlflow
print("torch     ", torch.__version__)
print("cuda      ", torch.cuda.is_available())
print("tracking  ", tracking_uri())
print("experiments", [e.name for e in mlflow.search_experiments()])
# Out:
# torch      2.13.0+cu130
# cuda       False
# tracking   http://mlflow:5000
# experiments ['yolo-plate-tuning', 'yolo-plate-detection', 'Default']

# %% [markdown]
# ## Split data
#
# Define same split before sweep.
#
# - sweep results are comparable based on the same split

# %%
from src.data_loader import build_split, verify_split, write_data_yaml

LIMIT = None
SEED = 0

# print split
print(build_split(RAW, PROCESSED, val_fraction=0.2, limit=LIMIT, seed=SEED))
print(verify_split(PROCESSED))

names = (RAW / "classes.txt").read_text().split()
data_yaml = write_data_yaml(ROOT / "configs" / "data.yaml", PROCESSED, names)
print(data_yaml.read_text())
# Out:
# {'train': 445, 'val': 111, 'orphan_images': 0, 'orphan_labels': 0}
# {'train': 445, 'val': 111}
# path: /workspace/data/processed
# train: train/images
# val: val/images
# nc: 1
# names: ['car_plate']

# %% [markdown]
# ## Define sweep (Grid search)
#
# `Grid search`:
#
# - Exhaustively tests every single **combination in a predefined matrix of values**.

# %%
import yaml

# experiment name
EXPERIMENT = "yolo-plate-tuning"

# load base param config
base_cfg = yaml.safe_load((ROOT / "configs" / "train.yaml").read_text())
base_cfg["project"] = str(ROOT / base_cfg["project"])

# define grid
GRID = [{"epochs": e, "name": f"tune-ep{e}"} for e in (10, 20, 30)]

print(f"experiment {EXPERIMENT}")
for g in GRID:
    print(" ", g)
# Out:
# experiment yolo-plate-tuning
#   {'epochs': 10, 'name': 'tune-ep10'}
#   {'epochs': 20, 'name': 'tune-ep20'}
#   {'epochs': 30, 'name': 'tune-ep30'}

# %% [markdown]
# ## Run sweep
#
# - Each config in grid becomes its own mlflow run
# - log with mlflow

# %%
from src.tracking import run_sweep

# run sweep with helper function
results = run_sweep(
    grid=GRID,
    base_cfg=base_cfg,
    data_yaml=data_yaml,
    processed_dir=PROCESSED,
    raw_dir=RAW,
    experiment=EXPERIMENT,
    run_name=lambda cfg: f"cpu-ep{cfg['epochs']}-{cfg['imgsz']}px",
)

for r in results:
    print(r)
# Out:
# ============================================================
# [1/3] cpu-ep10-416px  {'epochs': 10, 'name': 'tune-ep10'}
# ============================================================
# Ultralytics 8.4.116 🚀 Python-3.12.13 torch-2.13.0+cu130 CPU (Intel Core 5 120U)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=False, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/workspace/configs/data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=10, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=416, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=tune-ep10, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/workspace/runs, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/workspace/runs/tune-ep10, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    430867  ultralytics.nn.modules.head.Detect           [1, 16, None, [64, 128, 256]]
# YOLO11n summary: 182 layers, 2,590,035 parameters, 2,590,019 gradients, 6.5 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# WARNING ⚠️ train: Slow image access detected (ping: 4.6±0.5 ms, read: 13.5±11.6 MB/s, size: 168.1 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# train: Scanning /workspace/data/processed/train/labels... 445 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 445/445 269.0it/s 1.7s0.1s
# train: /workspace/data/processed/train/images/audi_a3_convertible_with_license_plate_18.jpeg: corrupt JPEG restored and saved
# train: /workspace/data/processed/train/images/audi_a3_convertible_with_license_plate_30.jpeg: corrupt JPEG restored and saved
# train: /workspace/data/processed/train/images/ford_focus_with_license_plate_15.jpeg: corrupt JPEG restored and saved
# train: New cache created: /workspace/data/processed/train/labels.cache
# WARNING ⚠️ val: Slow image access detected (ping: 3.5±0.5 ms, read: 26.5±20.4 MB/s, size: 222.5 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /workspace/data/processed/val/labels... 111 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 111/111 400.9it/s 0.3s1s
# val: New cache created: /workspace/data/processed/val/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Plotting labels to /workspace/runs/tune-ep10/labels.jpg...
# MLflow: logging run_id(f22c9ceeb8284ff9987baf3eb8f99590) to http://mlflow:5000
# MLflow: disable with 'yolo settings mlflow=False'
# Image sizes 416 train, 416 val
# Using 0 dataloader workers
# Logging results to /workspace/runs/tune-ep10
# Starting training for 10 epochs...
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10         0G      1.094      2.632          1          5        416: 100% ━━━━━━━━━━━━ 56/56 1.7s/it 1:361.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.1s/it 14.5s1.9s
#                    all        111        116     0.0037      0.957     0.0372     0.0218
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/10         0G      1.169       1.65      1.006          5        416: 100% ━━━━━━━━━━━━ 56/56 1.5s/it 1:221.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.8s/it 12.8s1.5s
#                    all        111        116      0.956      0.745       0.88      0.583
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/10         0G      1.124      1.456      1.004          5        416: 100% ━━━━━━━━━━━━ 56/56 1.5s/it 1:261.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.5s/it 10.4s.5ss
#                    all        111        116      0.897      0.822       0.89      0.627
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/10         0G      1.126      1.364     0.9799          5        416: 100% ━━━━━━━━━━━━ 56/56 1.4s/it 1:191.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.3s/it 9.1s1.3ss
#                    all        111        116       0.87      0.897       0.92      0.605
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/10         0G      1.036      1.179     0.9551          4        416: 100% ━━━━━━━━━━━━ 56/56 1.3s/it 1:151.0sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.9s/it 13.3s1.9s
#                    all        111        116      0.942      0.897      0.942      0.662
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/10         0G     0.9924      1.041     0.9413          5        416: 100% ━━━━━━━━━━━━ 56/56 1.7s/it 1:341.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.2s/it 8.2s1.4ss
#                    all        111        116      0.938      0.921      0.932      0.694
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/10         0G     0.9411     0.9601     0.9282          5        416: 100% ━━━━━━━━━━━━ 56/56 1.6s/it 1:291.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.9s/it 13.3s1.7s
#                    all        111        116      0.959      0.931      0.946      0.696
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/10         0G      0.897      0.892     0.9056          5        416: 100% ━━━━━━━━━━━━ 56/56 2.2s/it 2:051.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.7s/it 11.6s.9ss
#                    all        111        116      0.973      0.929      0.947      0.711
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/10         0G     0.8429     0.8164     0.8894          5        416: 100% ━━━━━━━━━━━━ 56/56 1.8s/it 1:401.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.1s/it 7.7s1.4ss
#                    all        111        116      0.989      0.931      0.947      0.744
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/10         0G     0.7929     0.7639     0.8738          5        416: 100% ━━━━━━━━━━━━ 56/56 1.7s/it 1:371.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.0it/s 6.8s1.1ss
#                    all        111        116      0.982      0.931      0.962      0.747
#
# 10 epochs completed in 0.290 hours.
# Optimizer stripped from /workspace/runs/tune-ep10/weights/last.pt, 5.4MB
# Optimizer stripped from /workspace/runs/tune-ep10/weights/best.pt, 5.4MB
#
# Validating /workspace/runs/tune-ep10/weights/best.pt...
# Ultralytics 8.4.116 🚀 Python-3.12.13 torch-2.13.0+cu130 CPU (Intel Core 5 120U)
# YOLO11n summary (fused): 101 layers, 2,582,347 parameters, 0 gradients, 6.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.1it/s 6.7s1.1ss
#                    all        111        116      0.982      0.931      0.962      0.747
# Speed: 0.6ms preprocess, 26.7ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to /workspace/runs/tune-ep10
# MLflow: results logged to http://mlflow:5000
# MLflow: disable with 'yolo settings mlflow=False'
# MLflow: mlflow run still alive, remember to close it using mlflow.end_run()
# 🏃 View run cpu-ep10-416px at: http://mlflow:5000/#/experiments/4/runs/f22c9ceeb8284ff9987baf3eb8f99590
# 🧪 View experiment at: http://mlflow:5000/#/experiments/4
# [1/3] done in 1074s
#
# ============================================================
# [2/3] cpu-ep20-416px  {'epochs': 20, 'name': 'tune-ep20'}
# ============================================================
# Ultralytics 8.4.116 🚀 Python-3.12.13 torch-2.13.0+cu130 CPU (Intel Core 5 120U)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=False, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/workspace/configs/data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=20, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=416, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=tune-ep20, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/workspace/runs, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/workspace/runs/tune-ep20, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    430867  ultralytics.nn.modules.head.Detect           [1, 16, None, [64, 128, 256]]
# YOLO11n summary: 182 layers, 2,590,035 parameters, 2,590,019 gradients, 6.5 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# WARNING ⚠️ train: Slow image access detected (ping: 3.2±0.6 ms, read: 21.6±12.5 MB/s, size: 163.1 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# train: Scanning /workspace/data/processed/train/labels.cache... 445 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 445/445 88.9Mit/s 0.0s
# train: /workspace/data/processed/train/images/audi_a3_convertible_with_license_plate_18.jpeg: corrupt JPEG restored and saved
# train: /workspace/data/processed/train/images/audi_a3_convertible_with_license_plate_30.jpeg: corrupt JPEG restored and saved
# train: /workspace/data/processed/train/images/ford_focus_with_license_plate_15.jpeg: corrupt JPEG restored and saved
# WARNING ⚠️ val: Slow image access detected (ping: 3.2±1.0 ms, read: 25.9±12.7 MB/s, size: 227.2 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /workspace/data/processed/val/labels.cache... 111 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 111/111 58.2Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Plotting labels to /workspace/runs/tune-ep20/labels.jpg...
# MLflow: logging run_id(599ed3f0c0a0465c83584ebdd3510884) to http://mlflow:5000
# MLflow: disable with 'yolo settings mlflow=False'
# Image sizes 416 train, 416 val
# Using 0 dataloader workers
# Logging results to /workspace/runs/tune-ep20
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/20         0G      1.148      2.428      1.025          8        416: 100% ━━━━━━━━━━━━ 56/56 1.8s/it 1:411.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.4s/it 9.6s1.6ss
#                    all        111        116     0.0034      0.974      0.302      0.227
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/20         0G      1.169      1.412     0.9853         14        416: 100% ━━━━━━━━━━━━ 56/56 1.6s/it 1:321.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.4s/it 10.1s.7ss
#                    all        111        116      0.632      0.488      0.577      0.385
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/20         0G      1.222      1.391      1.041          7        416: 100% ━━━━━━━━━━━━ 56/56 1.7s/it 1:331.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.2s/it 8.7s1.5ss
#                    all        111        116      0.742      0.716      0.792      0.498
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/20         0G      1.161      1.222      1.037         12        416: 100% ━━━━━━━━━━━━ 56/56 1.6s/it 1:321.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.3s/it 9.4s1.5ss
#                    all        111        116      0.901      0.888      0.929      0.643
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/20         0G      1.103      1.092      1.015          9        416: 100% ━━━━━━━━━━━━ 56/56 1.7s/it 1:341.4sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.4s/it 9.8s1.6ss
#                    all        111        116      0.969      0.871      0.954      0.682
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/20         0G      1.076      1.003      1.013         11        416: 23% ━━╸───────── 13/56 1.6s/it 24.3s<1:09

# %% [markdown]
# ## List experiment runs
#
# List emperiment runs for comparison.

# %%
from src.tracking import compare_runs

table = compare_runs(EXPERIMENT)
table

# %% [markdown]
# visualize historical metrics

# %%
import matplotlib.pyplot as plt

# get historical run metrics
client = mlflow.tracking.MlflowClient()
experiment = mlflow.get_experiment_by_name(EXPERIMENT)
runs = mlflow.search_runs(experiment_ids=[experiment.experiment_id])

fig, axes = plt.subplots(1, 2, figsize=(13, 4.5))
for _, row in runs.iterrows():
    label = row["tags.mlflow.runName"]
    for ax, metric in zip(axes, ("metrics/mAP50B", "metrics/mAP50-95B")):
        history = client.get_metric_history(row["run_id"], metric)
        if history:
            ax.plot([p.step for p in history], [
                    p.value for p in history], marker="o", ms=3, label=label)

for ax, metric in zip(axes, ("mAP50", "mAP50-95")):
    ax.set_xlabel("epoch")
    ax.set_ylabel(metric)
    ax.set_title(metric)
    ax.grid(alpha=0.3)
    ax.legend(fontsize=8)

plt.tight_layout()
plt.show()

# %%
# Cost against benefit -- more epochs always helps a little, so the question is
# whether the gain justifies the minutes.
cols = ["tags.mlflow.runName", "params.epochs", "metrics.metrics/mAP50-95B", "metrics.elapsed_seconds"]
cost = runs[[c for c in cols if c in runs.columns]].copy()
cost.columns = [c.split(".", 1)[-1] for c in cost.columns]
cost = cost.sort_values("epochs", key=lambda s: s.astype(int))
cost["min_per_0.01_mAP"] = (
    cost["elapsed_seconds"] / 60 / (cost["metrics/mAP50-95B"] * 100)
).round(2)
cost

# %% [markdown]
# Browse the runs at http://127.0.0.1:5000.
